# %% [markdown]
# # RNN Preprocessing

# %%
#utils check 
import utils_updated
from rnn import processText

#import packages
import string
import glove
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from collections import Counter
import warnings
warnings.filterwarnings("ignore")
import os
os.environ['KMP_DUPLICATE_LIB_OK'] = 'True'

# %% [markdown]
# ## I. Data Preprocessing

# %%
#load dataset
data = pd.read_csv('../data/papers.csv')
#preprocessing
dataNew = utils_updated.preprocessing(data, dropnan = True)
#check data## I. Data Preprocessing
dataNew.head()
# Out:
#      id  year                                              title event_type  \
# 0     1  1987  self-organization of associative database and ...        NaN
# 1    10  1987  a mean field theory of layer iv of visual cort...        NaN
# 2   100  1988  storing covariance by the associative long-ter...        NaN
# 3  1000  1994  bayesian query construction for neural network...        NaN
# 4  1001  1994  neural network ensembles, cross validation, an...        NaN
#
#                                             pdf_name  \
# 0  1-self-organization-of-associative-database-an...
# 1  10-a-mean-field-theory-of-layer-iv-of-visual-c...
# 2  100-storing-covariance-by-the-associative-long...
# 3  1000-bayesian-query-construction-for-neural-ne...
# 4  1001-neural-network-ensembles-cross-validation...
#
#                                             abstract  \
# 0  an efficient method of self-organizing associa...
# 1  a single cell theory for the development of se...
# 2   in modeling studies or memory based on neural...
# 3  if data collection is costly, there is much to...
# 4  learning of continuous valued functions using ...
#
#                                           paper_text  aLen  tLen
# 0  767  self-organization of associative database...    73     7
# 1  683  a mean field theory of layer iv of visual...    91    17
# 2  394  storing covariance by the associative lon...   300    15
# 3  bayesian query construction for neural network...    94     7
# 4  neural network ensembles, cross validation, an...   129     8

# %%
dataNew.shape
# Out:
# (7174, 9)

# %%
#visualize distribution 
fig, ax = plt.subplots(figsize = (10, 8))
ax.hist(dataNew.aLen, bins = 100)
ax.set_title('Distribution of Abstract Length', fontsize = 20)
plt.show()

# %%
#for now we use articles with a length less than 250
data250 = dataNew[dataNew.aLen <= 250]
data250.shape
# Out:
# (4638, 9)

# %%
print('Maximum title length: ', data250.tLen.max())
# Out:
# Maximum title length:  20

# %%
#tokenize data
prep = processText(data250[['title', 'abstract']].values.T)
#get dictionaries of word and tags
prep.getDictionary()
#update sequence length
prep.updateMaxLen()
print('Number of unique words: ', prep.nUnique)
print('Maxmimum sequence length: ', prep.maxLen)
# Out:
# Number of unique words:  32468
# Maxmimum sequence length:  250

# %%
#get tokenized vector of text
txtTokenized = prep.tokenize()
titles = txtTokenized[0]
abstracts = txtTokenized[1]
print('Example of tokenized title:\n {0} => {1}'.format(titles[0], [prep.idx2word[i] for i in titles[0]]))
print('Example of tokenized abstract:\n {0} => {1}'.format(abstracts[0],[prep.idx2word[i] for i in abstracts[0]]))
# Out:
# Example of tokenized title:
#  [3, 4, 5, 6, 7, 8, 9] => ['self-organization', 'of', 'associative', 'database', 'and', 'its', 'applications']
# Example of tokenized abstract:
#  [42, 466, 64, 4, 580, 5, 5497, 431, 5498, 5499, 51, 9, 19, 321, 5500, 5501, 58, 5498, 5497, 176, 5502, 3251, 503, 51, 309, 5503, 75, 58, 619, 5504, 1743, 4, 5505, 42, 61, 4, 3, 431, 5506, 368, 42, 1019, 4, 5507, 1727, 5508, 10, 289, 4072, 4, 21, 5509, 75, 58, 5510, 5504, 5511, 42, 5512, 19, 187, 1181, 92, 7, 122, 19, 42, 319, 320, 321, 159, 1391, 5513] => ['an', 'efficient', 'method', 'of', 'self-organizing', 'associative', 'databases', 'is', 'proposed', 'together', 'with', 'applications', 'to', 'robot', 'eyesight', 'systems.', 'the', 'proposed', 'databases', 'can', 'associate', 'any', 'input', 'with', 'some', 'output.', 'in', 'the', 'first', 'half', 'part', 'of', 'discussion,', 'an', 'algorithm', 'of', 'self-organization', 'is', 'proposed.', 'from', 'an', 'aspect', 'of', 'hardware,', 'it', 'produces', 'a', 'new', 'style', 'of', 'neural', 'network.', 'in', 'the', 'latter', 'half', 'part,', 'an', 'applicability', 'to', 'handwritten', 'letter', 'recognition', 'and', 'that', 'to', 'an', 'autonomous', 'mobile', 'robot', 'system', 'are', 'demonstrated.']

# %%
#split data into train, validation, and test set
trainX, testX, trainY, testY = train_test_split(abstracts, titles, test_size = 0.2 , random_state = 209)
trainX, valX, trainY, valY = train_test_split(trainX, trainY, test_size = 0.1 , random_state = 209)

print('Number of training samples: ', len(trainX))
print('Number of validation samples: ', len(valX))
print('Number of test samples: ', len(testX))
# Out:
# Number of training samples:  3339
# Number of validation samples:  371
# Number of test samples:  928

# %%
# #save dictionaries for future use
# import json
# histPath = 'rnn_training_history/'
# with open(histPath+'word2idx_master.json', 'w') as wiM, open(histPath+'idx2word_master.json', 'w') as iwM:
#     json.dump(prep.word2idx, wiM)
#     json.dump(prep.idx2word, iwM)

# %%
# #save train, val, and test
# import pickle
# with open(histPath+'train.txt', "wb") as f1, open(histPath+'val.txt', "wb") as f2, open(histPath+'test.txt', "wb") as f3:
#     pickle.dump((trainX,trainY), f1)
#     pickle.dump((valX, valY), f2)
#     pickle.dump((testX, testY), f3)

# %% [markdown]
# ---
#
# ## II. Train Embeddings

# %%
#load dictionaries
import pickle
with open(histPath+'word2idx_master.json', 'r') as f1, open(histPath+'idx2word_master.json', 'r') as f2:
    word2idx = json.load(f1)
    idx2word = json.load(f2)
#load training data
with open(histPath+'train.txt', "rb") as f: 
    trainX, trainY = pickle.load(f)

# %%
#get text for training
#remove ignored/disqualified words
trainX = [[idx2word[str(x)] for x in v if x != 2] for v in trainX]
trainY = [[idx2word[str(x)] for x in v if x != 2] for v in trainY]
embeddTxt = trainX + trainY

#prep dictionary for embedding training
#drop pad, eos, and ignore tag
start = 0
embeddDict = dict()
for vec in embeddTxt:
    for w in vec:
        if w not in embeddDict.keys():
            embeddDict[w] = start
            start += 1

# %%
print('Number of unique words for embedding training: ', len(embeddDict))
# Out:
# Number of unique words for embedding training:  27140

# %%
#train glove embedding 
#creating a corpus object
corpus_ = glove.Corpus(dictionary = embeddDict) 
#training the corpus to generate the co occurence matrix which is used in GloVe
# corpus_.fit(embeddTxt, window = 10)
corpus_.fit(embeddTxt, window = 5)

# %%
#creating a Glove object which will use the matrix created in the above lines to create embeddings
#We can set the learning rate as it uses Gradient Descent and number of components
glove_ = glove.Glove(no_components = 100, learning_rate = 0.01, random_state = 209)
glove_.fit(corpus_.matrix, epochs=50, no_threads=10, verbose = True)
glove_.add_dictionary(corpus_.dictionary)
# Out:
# Performing 50 training epochs with 10 threads
# Epoch 0
# Epoch 1
# Epoch 2
# Epoch 3
# Epoch 4
# Epoch 5
# Epoch 6
# Epoch 7
# Epoch 8
# Epoch 9
# Epoch 10
# Epoch 11
# Epoch 12
# Epoch 13
# Epoch 14
# Epoch 15
# Epoch 16
# Epoch 17
# Epoch 18
# Epoch 19
# Epoch 20
# Epoch 21
# Epoch 22
# Epoch 23
# Epoch 24
# Epoch 25
# Epoch 26
# Epoch 27
# Epoch 28
# Epoch 29
# Epoch 30
# Epoch 31
# Epoch 32
# Epoch 33
# Epoch 34
# Epoch 35
# Epoch 36
# Epoch 37
# Epoch 38
# Epoch 39
# Epoch 40
# Epoch 41
# Epoch 42
# Epoch 43
# Epoch 44
# Epoch 45
# Epoch 46
# Epoch 47
# Epoch 48
# Epoch 49

# %%
glove_.word_vectors.shape
# Out:
# (27140, 100)

# %%
glove_.dictionary
# Out:
# {'we': 0,
#  'propose': 1,
#  'a': 2,
#  'class': 3,
#  'of': 4,
#  'sparse': 5,
#  'coding': 6,
#  'models': 7,
#  'that': 8,
#  'utilizes': 9,
#  'laplacian': 10,
#  'scale': 11,
#  'mixture': 12,
#  'prior': 13,
#  'to': 14,
#  'model': 15,
#  'dependencies': 16,
#  'among': 17,
#  'coefficients.': 18,
#  'each': 19,
#  'coefficient': 20,
#  'is': 21,
#  'modeled': 22,
#  'as': 23,
#  'distribution': 24,
#  'with': 25,
#  'variable': 26,
#  'parameter,': 27,
#  'gamma': 28,
#  'over': 29,
#  'the': 30,
#  'parameter.': 31,
#  'show': 32,
#  'that,': 33,
#  'due': 34,
#  'conjugacy': 35,
#  'prior,': 36,
#  'it': 37,
#  'possible': 38,
#  'derive': 39,
#  'efficient': 40,
#  'inference': 41,
#  'procedures': 42,
#  'for': 43,
#  'both': 44,
#  'coefficients': 45,
#  'and': 46,
#  'when': 47,
#  'parameters': 48,
#  'group': 49,
#  'are': 50,
#  'combined': 51,
#  'into': 52,
#  'single': 53,
#  'variable,': 54,
#  'describe': 55,
#  'occur': 56,
#  'common': 57,
#  'amplitude': 58,
#  'fluctuations': 59,
#  'coefficients,': 60,
#  'which': 61,
#  'have': 62,
#  'been': 63,
#  'shown': 64,
#  'constitute': 65,
#  'large': 66,
#  'fraction': 67,
#  'redundancy': 68,
#  'in': 69,
#  'natural': 70,
#  'images.': 71,
#  'consequence': 72,
#  'this': 73,
#  'coding,': 74,
#  'resulting': 75,
#  'follows': 76,
#  'divisive': 77,
#  'normalization': 78,
#  'rule,': 79,
#  'may': 80,
#  'be': 81,
#  'efficiently': 82,
#  'implemented': 83,
#  'network': 84,
#  'architecture': 85,
#  'similar': 86,
#  'has': 87,
#  'proposed': 88,
#  'primary': 89,
#  'visual': 90,
#  'cortex.': 91,
#  'also': 92,
#  'demonstrate': 93,
#  'improvements': 94,
#  'image': 95,
#  'compressive': 96,
#  'sensing': 97,
#  'recovery': 98,
#  'using': 99,
#  'lsm': 100,
#  'model.': 101,
#  'humans': 102,
#  'learn': 103,
#  'speak': 104,
#  'before': 105,
#  'they': 106,
#  'can': 107,
#  'read': 108,
#  'or': 109,
#  'write,': 110,
#  'so': 111,
#  'why': 112,
#  'can?t': 113,
#  'computers': 114,
#  'do': 115,
#  'same?': 116,
#  'paper,': 117,
#  'present': 118,
#  'deep': 119,
#  'neural': 120,
#  'capable': 121,
#  'rudimentary': 122,
#  'spoken': 123,
#  'language': 124,
#  'acquisition': 125,
#  'untranscribed': 126,
#  'audio': 127,
#  'training': 128,
#  'data,': 129,
#  'whose': 130,
#  'only': 131,
#  'supervision': 132,
#  'comes': 133,
#  'form': 134,
#  'contextually': 135,
#  'relevant': 136,
#  'collection': 137,
#  'our': 138,
#  'data': 139,
#  'comprised': 140,
#  '120,000': 141,
#  'captions': 142,
#  'places': 143,
#  'dataset': 144,
#  'evaluate': 145,
#  'on': 146,
#  'an': 147,
#  'search': 148,
#  'annotation': 149,
#  'task.': 150,
#  'provide': 151,
#  'some': 152,
#  'visualizations': 153,
#  'suggest': 154,
#  'learning': 155,
#  'recognize': 156,
#  'meaningful': 157,
#  'words': 158,
#  'within': 159,
#  'caption': 160,
#  'spectrograms.': 161,
#  'computationally': 162,
#  'intensive': 163,
#  'distributed': 164,
#  'parallel': 165,
#  'computing': 166,
#  'often': 167,
#  'bottlenecked': 168,
#  'by': 169,
#  'small': 170,
#  'set': 171,
#  'slow': 172,
#  'workers': 173,
#  'known': 174,
#  'stragglers.': 175,
#  'utilize': 176,
#  'emerging': 177,
#  'idea': 178,
#  "computation''": 179,
#  'design': 180,
#  'novel': 181,
#  'error-correcting-code': 182,
#  'inspired': 183,
#  'technique': 184,
#  'solving': 185,
#  'linear': 186,
#  'inverse': 187,
#  'problems': 188,
#  'under': 189,
#  'specific': 190,
#  'iterative': 191,
#  'methods': 192,
#  'parallelized': 193,
#  'implementation': 194,
#  'affected': 195,
#  'example': 196,
#  'machine-learning': 197,
#  'applications': 198,
#  'include': 199,
#  'such': 200,
#  'personalized': 201,
#  'pagerank': 202,
#  'sampling': 203,
#  'graphs.': 204,
#  'provably': 205,
#  'coded-computation': 206,
#  'reduce': 207,
#  'mean-squared': 208,
#  'error': 209,
#  'computational': 210,
#  'deadline': 211,
#  'constraint.': 212,
#  'fact,': 213,
#  'ratio': 214,
#  'replication-based': 215,
#  'coded': 216,
#  'techniques': 217,
#  'diverges': 218,
#  'infinity': 219,
#  'increases.': 220,
#  'experiments': 221,
#  'performed': 222,
#  'real': 223,
#  'systems': 224,
#  'social': 225,
#  'networks': 226,
#  'further,': 227,
#  'unlike': 228,
#  'thus': 229,
#  'far,': 230,
#  'strategy': 231,
#  'combines': 232,
#  'outputs': 233,
#  'all': 234,
#  'workers,': 235,
#  'including': 236,
#  'stragglers,': 237,
#  'produce': 238,
#  'more': 239,
#  'accurate': 240,
#  'estimates': 241,
#  'at': 242,
#  'deadline.': 243,
#  'ensures': 244,
#  'accuracy': 245,
#  'degrades': 246,
#  'event': 247,
#  'number': 248,
#  'stragglers': 249,
#  'large.': 250,
#  'paper': 251,
#  'lower': 252,
#  'upper': 253,
#  'bounds': 254,
#  'support': 255,
#  'vectors': 256,
#  'derived': 257,
#  'vector': 258,
#  'machines': 259,
#  'based': 260,
#  'epsilon-insensitive': 261,
#  'loss': 262,
#  'function.': 263,
#  'turns': 264,
#  'out': 265,
#  'these': 266,
#  'asymptotically': 267,
#  'tight': 268,
#  'mild': 269,
#  'assumptions': 270,
#  'generating': 271,
#  'distribution.': 272,
#  'finally,': 273,
#  'briefly': 274,
#  'discuss': 275,
#  'trade-off': 276,
#  'epsilon': 277,
#  'between': 278,
#  'sparsity': 279,
#  'if': 280,
#  'svm': 281,
#  'used': 282,
#  'estimate': 283,
#  'conditional': 284,
#  'median.': 285,
#  'layered': 286,
#  'powerful': 287,
#  'way': 288,
#  'describing': 289,
#  'scenes': 290,
#  'containing': 291,
#  'smooth': 292,
#  'surfaces': 293,
#  'overlap': 294,
#  'occlude': 295,
#  'other.': 296,
#  'motion': 297,
#  'estimation,': 298,
#  'long': 299,
#  'history': 300,
#  'but': 301,
#  'not': 302,
#  'achieved': 303,
#  'wide': 304,
#  'use': 305,
#  'non-layered': 306,
#  'methods.': 307,
#  'new': 308,
#  'probabilistic': 309,
#  'optical': 310,
#  'flow': 311,
#  'layers': 312,
#  'addresses': 313,
#  'many': 314,
#  'shortcomings': 315,
#  'previous': 316,
#  'approaches.': 317,
#  'particular,': 318,
#  'define': 319,
#  'graphical': 320,
#  'explicitly': 321,
#  'captures:': 322,
#  'occlusions': 323,
#  'disocclusions;': 324,
#  'depth': 325,
#  'ordering': 326,
#  'layers;': 327,
#  'temporal': 328,
#  'consistency': 329,
#  'layer': 330,
#  'segmentation.': 331,
#  'additionally': 332,
#  'combination': 333,
#  'parametric': 334,
#  'deviation': 335,
#  'mrf': 336,
#  'robust': 337,
#  'spatial': 338,
#  'prior;': 339,
#  'allows': 340,
#  'roughness': 341,
#  'layers.': 342,
#  'key': 343,
#  'contribution': 344,
#  'formulation': 345,
#  'image-dependent': 346,
#  'hidden': 347,
#  'field': 348,
#  'recent': 349,
#  'static': 350,
#  'scene': 351,
#  'method': 352,
#  'achieves': 353,
#  'state-of-the-art': 354,
#  'results': 355,
#  'middlebury': 356,
#  'benchmark': 357,
#  'produces': 358,
#  'segmentations': 359,
#  'well': 360,
#  'detected': 361,
#  'occlusion': 362,
#  'regions.': 363,
#  'non-parametric': 364,
#  'multivariate': 365,
#  'density': 366,
#  'estimation': 367,
#  'faces': 368,
#  'strong': 369,
#  'statistical': 370,
#  'bottlenecks,': 371,
#  'practical': 372,
#  'approaches': 373,
#  'impose': 374,
#  'near-parametric': 375,
#  'functions.': 376,
#  'leverage': 377,
#  'developments': 378,
#  'very': 379,
#  'attractive': 380,
#  'properties.': 381,
#  'approach': 382,
#  'relies': 383,
#  'simple': 384,
#  'function': 385,
#  'space': 386,
#  'assumption': 387,
#  'conditioned': 388,
#  'other': 389,
#  'variables': 390,
#  'exponential': 391,
#  'family': 392,
#  'form.': 393,
#  'nonnegative': 394,
#  'matrix': 395,
#  'factorization': 396,
#  'popular': 397,
#  'analysis': 398,
#  'method,': 399,
#  'objective': 400,
#  'decompose': 401,
#  'components': 402,
#  'product': 403,
#  'two': 404,
#  'matrices.': 405,
#  'work,': 406,
#  'algorithm': 407,
#  'multi-factor': 408,
#  'problem': 409,
#  'generalizes': 410,
#  'original': 411,
#  'nmf': 412,
#  'than': 413,
#  'factors.': 414,
#  'furthermore,': 415,
#  'extend': 416,
#  'mfnmf': 417,
#  'incorporate': 418,
#  'regularizer': 419,
#  'dirichlet': 420,
#  'normalized': 421,
#  'columns': 422,
#  'encourage': 423,
#  'obtained': 424,
#  'affords': 425,
#  'closed': 426,
#  'intuitive': 427,
#  'interpretation,': 428,
#  'comparison': 429,
#  'works': 430,
#  'fix': 431,
#  'point': 432,
#  'iterations.': 433,
#  'effectiveness': 434,
#  'efficiency': 435,
#  'algorithms': 436,
#  'synthetic': 437,
#  'sets.': 438,
#  'maximum': 439,
#  'mean': 440,
#  'discrepancy': 441,
#  'kernel': 442,
#  'two-sample': 443,
#  'tests': 444,
#  'low': 445,
#  'sample': 446,
#  'complexity': 447,
#  'consistent.': 448,
#  'test': 449,
#  'hyperparameter': 450,
#  'one': 451,
#  'control': 452,
#  'tradeoff': 453,
#  'time.': 454,
#  'tests,': 455,
#  'denote': 456,
#  'b-tests,': 457,
#  'statistically': 458,
#  'efficient,': 459,
#  'combining': 460,
#  'favorable': 461,
#  'properties': 462,
#  'previously': 463,
#  'mmd': 464,
#  'tests.': 465,
#  'does': 466,
#  'better': 467,
#  'leveraging': 468,
#  'samples': 469,
#  'variance': 470,
#  'finite': 471,
#  'case,': 472,
#  'while': 473,
#  'avoiding': 474,
#  'quadratic': 475,
#  'evaluations': 476,
#  'complex': 477,
#  'null-hypothesis': 478,
#  'approximation': 479,
#  'would': 480,
#  'required': 481,
#  'relying': 482,
#  'u-statistics.': 483,
#  'b-test': 484,
#  'uses': 485,
#  'smaller': 486,
#  'avoids': 487,
#  'completely': 488,
#  'burden': 489,
#  'maintaining': 490,
#  'probabilistically': 491,
#  'conservative': 492,
#  'thresholds': 493,
#  'type': 494,
#  'i': 495,
#  'error.': 496,
#  'multiple': 497,
#  'kernels': 498,
#  'transfer': 499,
#  'seamlessly': 500,
#  'hypothesis': 501,
#  'test,': 502,
#  'allowing': 503,
#  'further': 504,
#  'increase': 505,
#  'discriminative': 506,
#  'power': 507,
#  'decrease': 508,
#  'complexity.': 509,
#  'posteriori}': 510,
#  'assignment': 511,
#  'crucial': 512,
#  'applications.': 513,
#  'several': 514,
#  'convergent': 515,
#  'successfully': 516,
#  'developed': 517,
#  'programming': 518,
#  'relaxation': 519,
#  'map': 520,
#  'problem.': 521,
#  'alternative': 522,
#  'approach,': 523,
#  'transforms': 524,
#  'bayes': 525,
#  'nets.': 526,
#  'then': 527,
#  'expectation': 528,
#  'maximization': 529,
#  'monotonically': 530,
#  'increases': 531,
#  'bound': 532,
#  'until': 533,
#  'convergence.': 534,
#  'update': 535,
#  'equations': 536,
#  'em': 537,
#  'remarkably': 538,
#  'simple,': 539,
#  'conceptually': 540,
#  'computationally,': 541,
#  'graph-based': 542,
#  'message': 543,
#  'passing': 544,
#  'paradigm': 545,
#  'max-product': 546,
#  'computation.': 547,
#  'experiment': 548,
#  'real-world': 549,
#  'protein': 550,
#  "em's": 551,
#  'convergence': 552,
#  'rate': 553,
#  'significantly': 554,
#  'higher': 555,
#  'lp': 556,
#  'mplp.': 557,
#  'solution': 558,
#  'quality': 559,
#  'optimal': 560,
#  'most': 561,
#  'instances': 562,
#  'order-of-magnitude': 563,
#  'faster': 564,
#  'commonly': 565,
#  'trained': 566,
#  '32-bit': 567,
#  'floating': 568,
#  'format.': 569,
#  'significant': 570,
#  'gains': 571,
#  'performance': 572,
#  'energy': 573,
#  'could': 574,
#  'realized': 575,
#  'numerical': 576,
#  'formats': 577,
#  'optimized': 578,
#  'learning.': 579,
#  'despite': 580,
#  'advances': 581,
#  'limited': 582,
#  'precision': 583,
#  'years,': 584,
#  'bit-width': 585,
#  'remains': 586,
#  'challenging': 587,
#  'here': 588,
#  'flexpoint': 589,
#  'format,': 590,
#  'aiming': 591,
#  'complete': 592,
#  'replacement': 593,
#  'format': 594,
#  'inference,': 595,
#  'designed': 596,
#  'modern': 597,
#  'topologies': 598,
#  'without': 599,
#  'modifications.': 600,
#  'tensors': 601,
#  'shared': 602,
#  'exponent': 603,
#  'dynamically': 604,
#  'adjusted': 605,
#  'minimize': 606,
#  'overflows': 607,
#  'maximize': 608,
#  'available': 609,
#  'dynamic': 610,
#  'range.': 611,
#  'validate': 612,
#  'alexnet,': 613,
#  'residual': 614,
#  'generative': 615,
#  'adversarial': 616,
#  'network,': 617,
#  'simulator': 618,
#  'framework.': 619,
#  '16-bit': 620,
#  'closely': 621,
#  'matches': 622,
#  'three': 623,
#  'models,': 624,
#  'any': 625,
#  'need': 626,
#  'tuning': 627,
#  'hyperparameters.': 628,
#  'promising': 629,
#  'future': 630,
#  'hardware': 631,
#  'inference.': 632,
#  'multi-output': 633,
#  'gaussian': 634,
#  'processes': 635,
#  'convenient': 636,
#  'framework': 637,
#  'multi-task': 638,
#  'problems.': 639,
#  'illustrative': 640,
#  'motivating': 641,
#  'multi-region': 642,
#  'electrophysiological': 643,
#  'time-series': 644,
#  'where': 645,
#  'experimentalists': 646,
#  'interested': 647,
#  'phase': 648,
#  'coherence': 649,
#  'channels.': 650,
#  'recently,': 651,
#  'wilson': 652,
#  'adams': 653,
#  'spectral': 654,
#  'task': 655,
#  'process': 656,
#  'develop': 657,
#  'covariance': 658,
#  'outputs,': 659,
#  'called': 660,
#  'cross-spectral': 661,
#  'kernel.': 662,
#  'new,': 663,
#  'flexible': 664,
#  'represents': 665,
#  'relationship': 666,
#  'observation': 667,
#  'expressive': 668,
#  'capabilities': 669,
#  'csm': 670,
#  'through': 671,
#  'bayesian': 672,
#  'markov': 673,
#  'model,': 674,
#  'emission': 675,
#  'presented': 676,
#  'measured': 677,
#  'data.': 678,
#  'identification': 679,
#  'noisy': 680,
#  'speech': 681,
#  'mixtures.': 682,
#  'block-based': 683,
#  'formulated': 684,
#  'incorporates': 685,
#  'time-varying': 686,
#  'harmonic': 687,
#  'plus': 688,
#  'noise': 689,
#  'latent': 690,
#  'sources': 691,
#  'observed': 692,
#  'convolutive': 693,
#  'pitches': 694,
#  'source': 695,
#  'signals,': 696,
#  'amplitudes': 697,
#  'phases': 698,
#  'sources,': 699,
#  'mixing': 700,
#  'filters': 701,
#  'statistics': 702,
#  'estimated': 703,
#  'likelihood,': 704,
#  'em-algorithm.': 705,
#  'exact': 706,
#  'averaging': 707,
#  'kalman': 708,
#  'smoother.': 709,
#  'pitch': 710,
#  'separation': 711,
#  'simultaneously.': 712,
#  'compared': 713,
#  'laryngograph': 714,
#  'measurements.': 715,
#  'artificial': 716,
#  'room': 717,
#  'mixtures': 718,
#  'viability': 719,
#  'approach.': 720,
#  'intelligible': 721,
#  'signals': 722,
#  're-synthesized': 723,
#  'from': 724,
#  'h+n': 725,
#  'models.': 726,
#  'introduction': 727,
#  'aim': 728,
#  'understand': 729,
#  'consider': 730,
#  'mixtures,': 731,
#  'xt': 732,
#  'l?1': 733,
#  'introduce': 734,
#  'quantile': 735,
#  'extends': 736,
#  'neighborhood': 737,
#  'selection': 738,
#  'meinshausen': 739,
#  'buhlmann': 740,
#  'latter': 741,
#  'defined': 742,
#  'basic': 743,
#  'subproblem': 744,
#  'modeling': 745,
#  'others.': 746,
#  'quantiles': 747,
#  'others,': 748,
#  'hence': 749,
#  'offers': 750,
#  'much': 751,
#  'richer,': 752,
#  'estimates.': 753,
#  'establish': 754,
#  'suitable': 755,
#  'regularity': 756,
#  'conditions,': 757,
#  'mqgm': 758,
#  'identifies': 759,
#  'independencies': 760,
#  'probability': 761,
#  'tending': 762,
#  'size': 763,
#  'grows,': 764,
#  'even': 765,
#  'outside': 766,
#  'usual': 767,
#  'homoskedastic': 768,
#  'fitting': 769,
#  'alternating': 770,
#  'direction': 771,
#  'multipliers.': 772,
#  'joint': 773,
#  'underlies': 774,
#  'estimate.': 775,
#  'lastly,': 776,
#  'detailed': 777,
#  'flexibility': 778,
#  'hetereoskedastic': 779,
#  'non-gaussian': 780,
#  'electrosensory': 781,
#  'system': 782,
#  'weakly': 783,
#  'electric': 784,
#  'fish,': 785,
#  'descending': 786,
#  'pathways': 787,
#  'first-order': 788,
#  'sensory': 789,
#  'nucleus': 790,
#  'influence': 791,
#  'gain': 792,
#  'its': 793,
#  'output': 794,
#  'neurons.': 795,
#  'underlying': 796,
#  'mechanisms': 797,
#  'subserve': 798,
#  'capability': 799,
#  'yet': 800,
#  'fully': 801,
#  'understood.': 802,
#  'mechanism': 803,
#  'involve': 804,
#  'regulation': 805,
#  'total': 806,
#  'membrane': 807,
#  'conductance': 808,
#  'how': 809,
#  'activity': 810,
#  'levels': 811,
#  'baseline': 812,
#  'excitation': 813,
#  'target': 814,
#  'neuron': 815,
#  'stacked': 816,
#  'denoising': 817,
#  'auto-encoders': 818,
#  'recently': 819,
#  'successful': 820,
#  'removing': 821,
#  'corrupted': 822,
#  'however,': 823,
#  'like': 824,
#  'techniques,': 825,
#  'ssda': 826,
#  'variation': 827,
#  'types': 828,
#  'beyond': 829,
#  'what': 830,
#  'seen': 831,
#  'during': 832,
#  'training.': 833,
#  'multi-column': 834,
#  'autoencoder,': 835,
#  'ssdas': 836,
#  'ssda.': 837,
#  'eliminate': 838,
#  'determine': 839,
#  'noise,': 840,
#  'let': 841,
#  'alone': 842,
#  'statistics,': 843,
#  'good': 844,
#  'variety': 845,
#  'different': 846,
#  'types,': 847,
#  'ones': 848,
#  'set.': 849,
#  'additionally,': 850,
#  'experimentally': 851,
#  'efficacy': 852,
#  'mc-ssda': 853,
#  'achieving': 854,
#  'mnist': 855,
#  'digit': 856,
#  'rates': 857,
#  'denoised': 858,
#  'images': 859,
#  'close': 860,
#  'uncorrupted': 861,
#  'ensure': 862,
#  'fresh': 863,
#  'applied': 864,
#  'network.': 865,
#  'existing': 866,
#  'orders': 867,
#  'magnitude': 868,
#  'practice': 869,
#  'indicates.': 870,
#  'work': 871,
#  'seeks': 872,
#  'narrow': 873,
#  'gap': 874,
#  'theory': 875,
#  'transforming': 876,
#  'determining': 877,
#  'supremum': 878,
#  'random': 879,
#  'weight': 880,
#  'vectors,': 881,
#  'turn': 882,
#  'attacked': 883,
#  'application': 884,
#  'poisson': 885,
#  'clumping': 886,
#  'heuristic.': 887,
#  'predictions': 888,
#  'oflifetimes': 889,
#  'allocated': 890,
#  'objects': 891,
#  'improve': 892,
#  'time': 893,
#  'memory': 894,
#  'management': 895,
#  'computer': 896,
#  'programs.': 897,
#  'barrett': 898,
#  'zorn': 899,
#  'lifetime': 900,
#  'predictor': 901,
#  'demonstrated': 902,
#  'improvement': 903,
#  'decision': 904,
#  'trees': 905,
#  'prediction': 906,
#  'same': 907,
#  'programs': 908,
#  'advantage': 909,
#  'features': 910,
#  'tree': 911,
#  'automatically': 912,
#  'choose': 913,
#  'subset.': 914,
#  'recursive': 915,
#  'teaching': 916,
#  'dimension': 917,
#  'concept': 918,
#  '1\\}^n$,': 919,
#  'introduced': 920,
#  'zilles': 921,
#  'et': 922,
#  'parameter': 923,
#  'worst-case': 924,
#  'labeled': 925,
#  'examples': 926,
#  'needed': 927,
#  'study': 928,
#  'quantitative': 929,
#  'relation': 930,
#  'rtd': 931,
#  'well-known': 932,
#  'measure': 933,
#  'vc': 934,
#  'best': 935,
#  'respect': 936,
#  'dimension.': 937,
#  'given': 938,
#  '1\\}^n$': 939,
#  'd$,': 940,
#  'first': 941,
#  '2^{d+1}$.': 942,
#  'depends': 943,
#  'independent': 944,
#  'its~domain': 945,
#  '2^d': 946,
#  'moran': 947,
#  'remove': 948,
#  'factor.': 949,
#  'classes': 950,
#  'c_k': 951,
#  '1}$': 952,
#  '3k$': 953,
#  'implies': 954,
#  'worst': 955,
#  'case': 956,
#  'largest': 957,
#  'was': 958,
#  'kuhlmann': 959,
#  'since': 960,
#  'then,': 961,
#  'no': 962,
#  'satisfy': 963,
#  'vcd(c)$.': 964,
#  'prove': 965,
#  'every': 966,
#  'polynomial': 967,
#  'degree': 968,
#  'decomposed': 969,
#  'sum': 970,
#  'convex': 971,
#  'concave': 972,
#  'polynomials.': 973,
#  'motivated': 974,
#  'property,': 975,
#  'exploit': 976,
#  'concave-convex': 977,
#  'procedure': 978,
#  'perform': 979,
#  'continuous': 980,
#  'fields': 981,
#  'potentials.': 982,
#  'decomposition': 983,
#  'polynomials': 984,
#  'expressed': 985,
#  'sum-of-squares': 986,
#  'optimization,': 987,
#  'solved': 988,
#  'via': 989,
#  'semidefinite': 990,
#  'programming.': 991,
#  'context': 992,
#  '3d': 993,
#  'reconstruction,': 994,
#  'shape': 995,
#  'shading': 996,
#  'denoising,': 997,
#  'outperforms': 998,
#  'terms': 999,
#  ...}

# %%
glove_.most_similar(word = 'experimentally', number = 10)
# Out:
# [('empirically', 0.9958726418710829),
#  ('call', 0.9930701433432622),
#  ('observe', 0.9929005544699466),
#  ('here', 0.9923985766964513),
#  ('experiments,', 0.9923766900055114),
#  ('assume', 0.9919521899560734),
#  ('finally,', 0.991356975403651),
#  ('we', 0.9908949609738834),
#  ('further', 0.9891162189128462)]

# %%
import numpy as np

# %%
scale = glove_.word_vectors.std()*np.sqrt(12)/2

#embedding matrix
# embeddMatrix = np.zeros((len(word2idx), 100))
embeddMatrix = np.random.uniform(low = -scale, high = scale, size = (len(word2idx), 100))
for i, w in enumerate(word2idx):
    try:
        embeddVec = glove_.word_vectors[glove_.dictionary[w]]
        embeddMatrix[i] = embeddVec
    except:
        continue

# %%
embeddMatrix.shape
# Out:
# (32471, 100)

# %%
#save trained embedding Matrix
np.save(histPath+'embeddMatrix_0510.npy', embeddMatrix)
